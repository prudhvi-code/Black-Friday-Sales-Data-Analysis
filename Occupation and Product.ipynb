# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("BlackFriday.csv")

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['Stay_In_Current_City_Years'],palette='Set3')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct='%.2f%%')
# Out:
# <Axes: >

# %%
sns.countplot(x='City_Category ',hue='Gender',data=df,palette='Set2')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years')['Gender'].value_counts()
# Out:
# Stay_In_Current_City_Years  Gender
# 0                           M          56161
#                             F          16564
# 1                           M         139197
#                             F          49995
# 2                           M          75741
#                             F          23718
# 3                           M          69420
#                             F          23892
# 4+                          M          64861
#                             F          18028
# Name: count, dtype: int64

# %%
df.groupby('Stay_In_Current_City_Years')['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years,Gender'>

# %%
df.groupby(['Stay_In_Current_City_Years', 'Gender', 'Marital_Status']).size().unstack()
# Out:
# Marital_Status                         0      1
# Stay_In_Current_City_Years Gender
# 0                          F        8894   7670
#                            M       35022  21139
# 1                          F       28561  21434
#                            M       79776  59421
# 2                          F       14229   9489
#                            M       45190  30551
# 3                          F       13897   9995
#                            M       42574  26846
# 4+                         F       11393   6635
#                            M       38281  26580

# %%
df.groupby(['Stay_In_Current_City_Years', 'Gender', 'Marital_Status']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years,Gender'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum()
# Out:
# Stay_In_Current_City_Years
# 0      672505429
# 1     1763243917
# 2      934676626
# 3      872531130
# 4+     774711276
# Name: Purchase, dtype: int64

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean()
# Out:
# Stay_In_Current_City_Years
# 0     9247.238625
# 1     9319.865095
# 2     9397.607316
# 3     9350.685121
# 4+    9346.370158
# Name: Purchase, dtype: float64

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x='Occupation',hue='Occupation',data=df,palette='Set2')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size()
# Out:
# Occupation
# 0     68120
# 1     45971
# 2     25845
# 3     17366
# 4     70862
# 5     11985
# 6     19822
# 7     57806
# 8      1524
# 9      6153
# 10    12623
# 11    11338
# 12    30423
# 13     7548
# 14    26712
# 15    11812
# 16    24790
# 17    39090
# 18     6525
# 19     8352
# 20    32910
# dtype: int64

# %%
df.groupby('Occupation').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].sum().sort_values(ascending=False)
# Out:
# Occupation
# 4     657530393
# 0     625814811
# 7     549282744
# 1     414552829
# 17    387240355
# 12    300672105
# 20    292276985
# 14    255594745
# 16    234442330
# 2     233275393
# 6     185065697
# 3     160428450
# 15    116540026
# 10    114273954
# 5     112525355
# 11    105437359
# 19     73115489
# 13     71135744
# 18     60249706
# 9      53619309
# 8      14594599
# Name: Purchase, dtype: int64

# %%
df.groupby('Occupation')['Purchase'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %%
sns.countplot(x='Occupation',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x='Occupation',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation')['Product_ID'].nunique()
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %%
df.groupby('Occupation')['Product_ID'].nunique().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size()
# Out:
# Product_Category_1
# 1     138353
# 2      23499
# 3      19849
# 4      11567
# 5     148592
# 6      20164
# 7       3668
# 8     112132
# 9        404
# 10      5032
# 11     23960
# 12      3875
# 13      5440
# 14      1500
# 15      6203
# 16      9697
# 17       567
# 18      3075
# dtype: int64

# %%
df.groupby('Product_Category_1').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values()
# Out:
# Product_Category_1
# 13       3931050
# 12       5235883
# 17       5758702
# 9        6277472
# 18       9149071
# 14      19718178
# 4       26937957
# 7       60059209
# 15      91658147
# 10      99029631
# 11     112203088
# 16     143168035
# 3      200412211
# 2      264497242
# 6      319355286
# 8      840693394
# 5      926917497
# 1     1882666325
# Name: Purchase, dtype: int64

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].mean().sort_values(ascending=False)
# Out:
# Product_Category_1
# 10    19679.974364
# 7     16373.830153
# 6     15837.893573
# 9     15538.297030
# 15    14776.422215
# 16    14764.157471
# 1     13607.701495
# 14    13145.452000
# 2     11255.680752
# 17    10156.440917
# 3     10096.841705
# 8      7497.354850
# 5      6238.004045
# 11     4682.933556
# 18     2975.307642
# 4      2328.862886
# 12     1351.195613
# 13      722.619485
# Name: Purchase, dtype: float64

# %%
df.groupby('Product_Category_1')['Purchase'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values(ascending=False)
# Out:
# Product_ID
# P00025442    27532426
# P00110742    26382569
# P00255842    24652442
# P00184942    24060871
# P00059442    23948299
# P00112142    23882624
# P00110942    23232538
# P00237542    23096487
# P00057642    22493690
# P00010742    21865042
# Name: Purchase, dtype: int64

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>
