# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("BlackFriday.csv")

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').size().plot(kind='bar',figsize=(8,6),title='Age Distribution')
# Out:
# <Axes: title={'center': 'Age Distribution'}, xlabel='Age'>

# %%
df['Age'].value_counts()
# Out:
# Age
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: count, dtype: int64

# %%
df[df['Age']=='26-35']['Product_ID'].nunique()
# Out:
# 3419

# %%
for i in df['Age'].unique():
    print(i,':',df[df['Age']==i]['Product_ID'].nunique())
# Out:
# 0-17 : 2300
# 55+ : 2573
# 26-35 : 3419
# 46-50 : 3099
# 51-55 : 2877
# 36-45 : 3318
# 18-25 : 3213

# %%
lst=[]
for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])

# %%
data=pd.DataFrame(lst,columns=['Age','Products'])

# %%
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot(kind='bar')
# Out:
# <Axes: >

# %%
data.plot.bar(x='Age',y='Products',figsize=(8,6))
# Out:
# <Axes: xlabel='Age'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %%
df['Age']
# Out:
# 0          0-17
# 1          0-17
# 2          0-17
# 3          0-17
# 4           55+
#           ...
# 537572    36-45
# 537573    36-45
# 537574    36-45
# 537575    36-45
# 537576    36-45
# Name: Age, Length: 537577, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 41.0+ MB

# %%
df['Age']
# Out:
# 0          0-17
# 1          0-17
# 2          0-17
# 3          0-17
# 4           55+
#           ...
# 537572    36-45
# 537573    36-45
# 537574    36-45
# 537575    36-45
# 537576    36-45
# Name: Age, Length: 537577, dtype: object

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df.groupby('Age').agg({'Purchase': 'mean'}).plot(
    kind='pie', y='Purchase', autopct='%1.1f%%', startangle=90, figsize=(6,6)
)
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Age').agg({'Purchase': 'sum'}).plot(
    kind='pie', y='Purchase', autopct='%1.1f%%', startangle=90, figsize=(6,6)
)
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind='bar',figsize=(8,6))
# Out:
# <Axes: xlabel='Marital_Status'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie',figsize=(8,6),autopct='%.2f')
# Out:
# <Axes: >

# %%
df.groupby('Age')['Purchase'].sum().plot.pie(
    autopct='%1.1f%%',figsize=(6,6)
)
# Out:
# <Axes: ylabel='Purchase'>
